# %%
# 8개의 날자 데이터 생성
import pandas as pd
index = pd.date_range('1/1/2000', periods =8)
print(index)
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
# DataFrame 생성 8*3 index=날자
import numpy as np
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df
# Out:
#                    A         B         C
# 2000-01-01  0.268605  0.452492  0.455062
# 2000-01-02  0.419032  0.518093  0.700258
# 2000-01-03  0.561771  0.066246  0.369805
# 2000-01-04  0.548437  0.986423  0.391666
# 2000-01-05  0.279422  0.614540  0.218374
# 2000-01-06  0.775406  0.574943  0.695634
# 2000-01-07  0.765798  0.708700  0.182448
# 2000-01-08  0.539966  0.931075  0.886174

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
print(df['B'])
# Out:
# 2000-01-01    0.135157
# 2000-01-02    0.044105
# 2000-01-03    0.243871
# 2000-01-04    0.871697
# 2000-01-05    0.289451
# 2000-01-06    0.377946
# 2000-01-07    0.386440
# 2000-01-08    0.584654
# Freq: D, Name: B, dtype: float64

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
print(df['B'] > 0.4)
# Out:
# 2000-01-01     True
# 2000-01-02     True
# 2000-01-03     True
# 2000-01-04     True
# 2000-01-05    False
# 2000-01-06     True
# 2000-01-07     True
# 2000-01-08     True
# Freq: D, Name: B, dtype: bool

# %%
df2 = df[df['B'] > 0.4]
df2
# Out:
#                    A         B         C
# 2000-01-01  0.618219  0.589920  0.441581
# 2000-01-02  0.459179  0.843574  0.303864
# 2000-01-03  0.700452  0.618304  0.060302
# 2000-01-04  0.564873  0.680932  0.900640
# 2000-01-06  0.107958  0.523444  0.500662
# 2000-01-07  0.592770  0.737282  0.793392
# 2000-01-08  0.787407  0.783966  0.091555

# %%
df2 = df2.T
df2
# Out:
#    2000-01-01  2000-01-02  2000-01-03  2000-01-04  2000-01-06  2000-01-07  \
# A    0.618219    0.459179    0.700452    0.564873    0.107958    0.592770
# B    0.589920    0.843574    0.618304    0.680932    0.523444    0.737282
# C    0.441581    0.303864    0.060302    0.900640    0.500662    0.793392
#
#    2000-01-08
# A    0.787407
# B    0.783966
# C    0.091555

# %%
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df['D'] = df['A'] / df['B']  # A열의 값을 B열의 값으로 나눈 값을 D열에 저장
df
# Out:
#                    A         B         C          D
# 2000-01-01  0.725083  0.168693  0.316572   4.298239
# 2000-01-02  0.580489  0.897436  0.914845   0.646830
# 2000-01-03  0.748748  0.048160  0.029478  15.546959
# 2000-01-04  0.325436  0.226283  0.216133   1.438183
# 2000-01-05  0.989104  0.340546  0.678304   2.904460
# 2000-01-06  0.609424  0.746126  0.666293   0.816785
# 2000-01-07  0.412483  0.087394  0.001287   4.719782
# 2000-01-08  0.728107  0.596814  0.768502   1.219991

# %%
# 행의 합 구하기
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df['D'] = df['A'] / df['B'] # 새로운 계산 열 추가
df['E'] = np.sum(df, axis = 1)  # 열방향(axis=1) 총합을 E 열에 저장
df.head()
# Out:
#                    A         B         C         D         E
# 2000-01-01  0.705186  0.466517  0.348742  1.511598  3.032043
# 2000-01-02  0.969441  0.998941  0.812886  0.970469  3.751738
# 2000-01-03  0.053944  0.079945  0.144267  0.674767  0.952923
# 2000-01-04  0.465613  0.431338  0.130813  1.079461  2.107226
# 2000-01-05  0.769872  0.937777  0.053032  0.820954  2.581634

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df['D'] = df['A'] / df['B']
df['E'] = np.sum(df, axis = 1)
df2 = df.sub(df['A'], axis =0)  # df에서 A열의 데이터를 뺄셈
print(df.head())
print(df2.head())
# Out:
#                    A         B         C          D          E
# 2000-01-01  0.542763  0.051231  0.436915  10.594439  11.625348
# 2000-01-02  0.386158  0.751446  0.576852   0.513886   2.228342
# 2000-01-03  0.532909  0.107394  0.266234   4.962199   5.868735
# 2000-01-04  0.204484  0.218446  0.865258   0.936087   2.224275
# 2000-01-05  0.439929  0.114583  0.376155   3.839402   4.770070
#               A         B         C          D          E
# 2000-01-01  0.0 -0.491532 -0.105848  10.051676  11.082585
# 2000-01-02  0.0  0.365289  0.190695   0.127728   1.842185
# 2000-01-03  0.0 -0.425515 -0.266675   4.429290   5.335826
# 2000-01-04  0.0  0.013961  0.660773   0.731603   2.019791
# 2000-01-05  0.0 -0.325347 -0.063774   3.399473   4.330140

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df['D'] = df['A'] / df['B']
df['E'] = np.sum(df, axis = 1)
df = df.sub(df['A'], axis =0)  
df = df.div(df['C'], axis = 0)   #C열의 데이터를 기준으로 열 우선 계산
df.to_csv('test.csv')
df.head()
# Out:
#               A         B    C          D          E
# 2000-01-01  0.0  0.969025  1.0   0.031995   9.132809
# 2000-01-02 -0.0  1.270897  1.0 -19.853117 -21.720048
# 2000-01-03 -0.0 -0.815342  1.0  -0.676290  -4.264688
# 2000-01-04 -0.0  3.140599  1.0 -21.579379 -29.318166
# 2000-01-05  0.0 -0.218897  1.0   5.011819  10.373272

# %%
import pandas as pd
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0)
df.head()
# Out:
#                                 총인구수  연령구간인구수     0세     1세     2세     3세  \
# 행정구역
# 서울특별시  (1100000000)          9857426  9857426  61253  70532  74322  72482
# 서울특별시 종로구 (1111000000)        154770   154770    652    794    911    895
# 서울특별시 종로구 청운효자동(1111051500)    13272    13272     81     82     90    105
# 서울특별시 종로구 사직동(1111053000)       9441     9441     43     63     75     68
# 서울특별시 종로구 삼청동(1111054000)       2907     2907     12      4     22     13
#
#                                 4세     5세     6세     7세  ...   91세   92세  \
# 행정구역                                                     ...
# 서울특별시  (1100000000)          71688  78941  75386  75929  ...  5892  4695
# 서울특별시 종로구 (1111000000)         859   1046    909   1012  ...   149   115
# 서울특별시 종로구 청운효자동(1111051500)     97    116    117    116  ...    12    14
# 서울특별시 종로구 사직동(1111053000)       76     81     74     83  ...    11    13
# 서울특별시 종로구 삼청동(1111054000)       12     13     20     11  ...     5     2
#
#                               93세   94세   95세   96세   97세   98세  99세  100세 이상
# 행정구역
# 서울특별시  (1100000000)          3589  3501  2569  1851  1436  1010  736     5519
# 서울특별시 종로구 (1111000000)         95    79    81    60    46    37   26      226
# 서울특별시 종로구 청운효자동(1111051500)     7     7     8     3     5     1    1       17
# 서울특별시 종로구 사직동(1111053000)       7     5     7     3     6     4    4       17
# 서울특별시 종로구 삼청동(1111054000)       3     3     2     2     0     2    1        7
#
# [5 rows x 103 columns]

# %%
import pandas as pd
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0)
df = df.div(df['총인구수'], axis =0)     # 전체 데이터를 총인구수로 나눠서 비율로 변환
del df['총인구수'], df['연령구간인구수']  # 총인구수, 연령구간인구수 열 삭제

# %%
name = input('원하는 지역의 이름을 입력해주세요 : ') #2. 지역 이름 입력
a = df.index.str.contains(name) #3. 해당 행을 찾아서 해당 지역의 인구 구조를 저장
df2 = df[a]
df2
# Out:
# 원하는 지역의 이름을 입력해주세요 : 신도림
#                                   0세       1세        2세        3세        4세  \
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)  0.010077  0.01101  0.011649  0.010983  0.011276
#
#                                   5세        6세        7세        8세        9세  \
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)  0.011143  0.012449  0.011036  0.011036  0.011089
#
#                             ...       91세       92세       93세       94세  \
# 행정구역                        ...
# 서울특별시 구로구 신도림동(1153051000)  ...  0.000613  0.000347  0.000187  0.000267
#
#                                 95세      96세      97세       98세       99세  \
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)  0.00016  0.00008  0.00008  0.000053  0.000053
#
#                             100세 이상
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)  0.00016
#
# [1 rows x 101 columns]

# %%
import matplotlib.pyplot as plt
plt.rc('font', family ='Malgun Gothic')
df2.T.plot()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family ='Malgun Gothic')
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0) 
df = df.div(df['총인구수'], axis = 0)     # ①-1. 전체 데이터를 총인구수로 나눠서 비율로 변환
del df['총인구수'], df['연령구간인구수']  # ①-2. 총인구수, 연령구간인구수 열 삭제
name = input('원하는 지역의 이름을 입력해주세요 : ')  # ② 지역 이름 입력
a = df.index.str.contains(name)  # ③ 해당 행을 찾아서 해당 지역의 인구 구조를 저장
df2 = df[a]
df3=df.loc[np.power(df.sub(df2.iloc[0], axis = 1), 2).sum(axis = 1).sort_values().index[:5]]
df3.T.plot()
plt.show()
# Out:
# 원하는 지역의 이름을 입력해주세요 : 대치1동
